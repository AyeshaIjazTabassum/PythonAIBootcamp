# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshaIjazTabassum/PythonAIBootcamp/blob/main/Day26.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Chat model Conversation User

# %%
! pip install langchain_core
! pip install langchain_google_genai

# %%
from langchain_core.messages import SystemMessage , AIMessage , HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('API')

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", api_key=GOOGLE_API_KEY)

# %%
#use  a list to store messages
chat_history=[]
System_Message=SystemMessage("You are  a helpful AI assistant")
chat_history.append(System_Message)
print("How can i help you?")
while True:
    user_message = input("You: ")
    #check if user wants to quit
    if user_message == "quit" or user_message == "exit":
        break
    chat_history.append(HumanMessage(content=user_message))
    print(f"You : {user_message}")
    #get AI response using history
    response =llm.invoke(chat_history)
    result=response.content
    chat_history.append(AIMessage(content=result))
    print(f"AI : {result}")

print("--Message History--")
print(chat_history)
# Out:
# How can i help you?
# You: What is Deep Learning?
# You : What is Deep Learning?
# AI : Deep learning is a **subset of machine learning** that uses **artificial neural networks** with multiple layers (hence "deep") to learn from and make decisions based on data. Think of it as a way to teach computers to learn like humans, by building complex models that can recognize patterns and make predictions.
#
# Here's a breakdown of the key concepts:
#
# **1. Artificial Neural Networks (ANNs):**
# *   **Inspiration:** ANNs are loosely inspired by the structure and function of the human brain's biological neural networks.
# *   **Neurons (Nodes):** They consist of interconnected "neurons" or nodes, organized in layers. Each neuron receives input, performs a simple computation, and passes its output to other neurons.
# ...
