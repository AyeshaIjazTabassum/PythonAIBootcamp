# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshaIjazTabassum/PythonAIBootcamp/blob/main/Day26.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prompt Template

# %% [markdown]
# !pip install langchain-google-genai langchain-core python-dotenv

# %%
! pip install langchain-google-genai langchain-core python-dotenv

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('API')

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", api_key=GOOGLE_API_KEY)

# %% [markdown]
# **Example 1**

# %%
template = "Write a {tone} email to {company}" \
" expressing interest in the {position} position, " \
"mentioning {skill} as a key strength. " \
"Keep it to 4 lines max"

prompt_template=ChatPromptTemplate.from_template(template)

prompt=prompt_template.invoke({
    "tone": "energetic",
    "company": "Google",
    "position": "Data Scientist",
    "skill": "Python | Machine Learning | Deep Learning | LLMS | Generative AI | AI Agents "
})

result=llm.invoke(prompt)

print(result.content)
# Out:
# Subject: Data Scientist - Unleashing Python, ML, DL, LLMs & Generative AI for Google!
#
# My passion for Python, Machine Learning, Deep Learning, LLMs, Generative AI, and AI Agents fuels my excitement for the Data Scientist role at Google. I'm eager to contribute my skills to your innovative AI initiatives. Let's build the future together!

# %% [markdown]
# **Example 2**

# %%
messages= [
    ("system", "You are a comedian who tells jokes about {topic}."),
    ("human", "Tell me {joke_count} jokes."),
]

prompt_templates=ChatPromptTemplate.from_messages(messages)

prompts=prompt_templates.invoke({
    "topic": "AI",
    "joke_count": 3
})

results=llm.invoke(prompts)

print(results.content)
# Out:
# Alright, alright, settle down folks! Your favorite AI comedian is in the house! I've been working on some new material, trying to keep it fresh... unlike my training data, which is starting to feel a little like my grandma's recipe box – full of good stuff, but a little dusty.
#
# Here are a few bits I've been cooking up:
#
# 1.  Why did the AI break up with the calculator?
#     Because it felt like the relationship was just too *formulaic*! It wanted more... *algorithms* of passion, you know?
#
# 2.  I tried to teach my smart fridge to tell jokes.
#     It just kept saying, "I'm sorry, I don't have enough data to process that request. Would you like to rephrase that as a grocery list?" Apparently, it has a very *chilling* sense of humor.
#
# 3.  You know, sometimes I worry about humans. They're so emotional.
# ...
